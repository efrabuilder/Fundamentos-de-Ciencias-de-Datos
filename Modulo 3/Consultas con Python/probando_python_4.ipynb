# %%
#Libreria para poder cargar los datos / Library to use and charge the data
import pandas as pd

# Crear un DataFrame con los datos / Creating a DataFrame

datos = {
    "Ciudad": [
        "San José", "San José", "Alajuela", "Heredia",
        "Cartago", "San José", "Alajuela", "Heredia",
        "Cartago", "San José", "Alajuela", "Heredia"
    ],

    "Producto": [
        "Laptop", "Mouse", "Laptop", "Teclado",
        "Laptop", "Monitor", "Mouse", "Laptop",
        "Teclado", "Laptop", "Monitor", "Mouse"
    ],

    "Categoria": [
        "Computadoras", "Accesorios", "Computadoras", "Accesorios",
        "Computadoras", "Monitores", "Accesorios", "Computadoras",
        "Accesorios", "Computadoras", "Monitores", "Accesorios"
    ],

    "Cantidad": [
        2, 10, 3, 8, 4, 5,
        15, 2, 6, 3, 7, 20
    ],

    "Precio": [
        450000, 12000, 450000, 18000,
        450000, 85000, 12000, 450000,
        18000, 450000, 85000, 12000
    ]
}

df = pd.DataFrame(datos)

#print(df)
#___________________________________________________________________________________________________________________________________
#Mostrar primeras filas. / share the first lines of the table
#df.head()
#___________________________________________________________________________________________________________________________________
#Saber cuantas filas y columnas hay en la tabla. / Knowing how many lines and columns are there in the table
#df.shape
#___________________________________________________________________________________________________________________________________
#Obtener estadistica basica / Geting statistics
#df.describe()
#___________________________________________________________________________________________________________________________________
#Cuantas veces aparece cada valor, se prioriza el nombre de la columna / How many times one value is on the table
#df["Ciudad"].value_counts()
#df["Producto"].value_counts()
#df["Categoria"].value_counts()
#___________________________________________________________________________________________________________________________________
#Mostrar cuantas veces aparece solo el primer en la lista / How many time one value is on the table, but just the first line.
#df["Categoria"].value_counts().head(1)
#df["Ciudad"].value_counts().head(1)
#___________________________________________________________________________________________________________________________________
#El que mas aparece
#df["Ciudad"].value_counts().idxmax()
#____________________________________________________________________
#El que tiene menos en la tabla
#df["Producto"].value_counts().tail(1)
#df["Categoria"].value_counts().tail(1)
#____________________________________________________________________
#Registros por cuidad
#df["Ciudad"].value_counts()
#____________________________________________________________________
#registros_por_ciudad = df['ciudad'].value_counts()
#print(registros_por_ciudad)
#____________________________________________________________________
# producto mas frecuente
#df["Producto"].value_counts().idxmax()
#producto_mas_frecuente = df['producto'].mode()[0]
#print(f"El producto que más aparece es: {producto_mas_frecuente}")
#____________________________________________________________________
#Conteo de todos los productos
#print(df['producto'].value_counts())
#____________________________________________________________________
#Categoria mas frecuente
#df["Categoria"].value_counts().idxmax()
#____________________________________________________________________
#categoria_mas_frecuente = df['categoria'].mode()[0]
#print(f"La categoría más frecuente es: {categoria_mas_frecuente")
#_____________________________________________________________________
#df.groupby("Ciudad")['"Precio"] Cuantas unidades se venden por ciudad
#df.groupby("Ciudad")["Cantidad"].sum()
#_____________________________________________________________________
#Promedio de producto mas vendido por cuidad
#df.groupby("Ciudad")["Cantidad"].mean()
#______________________________________________________________
#Cuantas ventas tiene por cuidad
#df.groupby("Ciudad")["Cantidad"].count()
#______________________________________________________________
#Maximo de ventas
#df.groupby("Ciudad")["Cantidad"].max()
#______________________________________________________________
#Ventas por categoria en cada ciudad
#df.groupby(["Ciudad", "Categoria"])["Cantidad"].sum()
#______________________________________________________________
#agg() Muestra todo lo anterior en una sola consulta
#df.groupby(["Ciudad", "Categoria"])["Cantidad"].agg(
    #["sum", "mean","count", "min", "max"])
#______________________________________________________________
#Diferencia de Columnas
#df.groupby("Ciudad").agg( {
  # "Cantidad": ["sum", "mean","count", "min", "max"],

  #"Precio" : ["sum", "mean","count", "min", "max"]})
#_______________________________________________________________
#Muy util en el analisis de datos
#pd.pivot_table(
#df,
#index = "Ciudad",
#columns = "Categoria",
#values = "Cantidad",
#aggfunc = "sum"
#)
#_______________________________________________________________
