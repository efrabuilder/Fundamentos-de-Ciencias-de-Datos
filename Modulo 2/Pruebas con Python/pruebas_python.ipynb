# %%
#Pedir dos numeros y sumarlos
print("Digite los numeros")
numero1 = float (input("Ingrese el primer numero :"))
numero2 = float (input("Ingrese el segundo numero :"))

# Sumar ambos números
suma = numero1 + numero2


# Mostrar el resultado
print(f"La suma es: {suma}")  #("La suma es: ", suma)
# Out:
# Digite los numeros
# Ingrese el primer numero :80
# Ingrese el segundo numero :49
# La suma es: 129.0
# La resta es: 31.0
# La multiplicacion es: 3920.0
# La division es: 1.6326530612244898

# %%
#Pedir dos numeros y restarlos
print("Digite los numeros")
numero1 = float (input("Ingrese el primer numero :"))
numero2 = float (input("Ingrese el segundo numero :"))

# restar ambos números
resta = numero1 - numero2

# Mostrar el resultado
print(f"La resta es: {resta}")  #("La resta es: ", resta)

# %%
#Pedir dos numeros y multiplicarlos
print("Digite los numeros")
numero1 = float (input("Ingrese el primer numero :"))
numero2 = float (input("Ingrese el segundo numero :"))

# multiplicar ambos números
multiplicacion = numero1 * numero2

# Mostrar el resultado
print(f"La multiplicacion es: {multiplicacion}")  #("La multiplicacion es: ", multiplicacion)
# Out:
# Digite los numeros
# Ingrese el primer numero :30
# Ingrese el segundo numero :50
# La suma es: 1500.0

# %%
#Pedir dos numeros y dividirlos
print("Digite los numeros")
numero1 = float (input("Ingrese el primer numero :"))
numero2 = float (input("Ingrese el segundo numero :"))

# dividir ambos números
division = numero1 / numero2

# Mostrar el resultado
print(f"La division es: {division}")  #("La division es: ", division)
# Out:
# Digite los numeros
# Ingrese el primer numero :50.26
# Ingrese el segundo numero :30
# La division es: 1.6753333333333333

# %%
#Pedir dos numeros y sumarlos
print("Digite los numeros")
numero1 = float (input("Ingrese el primer numero :"))
numero2 = float (input("Ingrese el segundo numero :"))

# Sumar ambos números
suma = numero1 + numero2
resta = numero1 - numero2
multiplicacion = numero1 * numero2
division = numero1 / numero2

# Mostrar el resultado
print(f"La suma es: {suma}")  #("La suma es: ", suma)
print(f"La resta es: {resta}")  #("La resta es: ", resta)
print(f"La multiplicacion es: {multiplicacion}")  #("La multiplicacion es: ", multiplicacion)
print(f"La division es: {division}")  #("La division es: ", division)
